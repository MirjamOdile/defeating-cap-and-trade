# %% [markdown]
# # Match the *DeSmog* Denialists
#
# #### This script extracts the matches all witnesses to known denialists and denialit organisations from the *DeSmog* Database

# %%
from TextCollection import *

# %%
# # Reinstantiate class after changing the Textcollection.py script
# # Do not run this in the last run! Leads to a conflict with pickle.

# from importlib import reload

# os.chdir('/home/mirjam/OneDrive/congress_committees/ArticleOne/Article_Scripts/Hearings')
# import TextCollection; reload(TextCollection)

# # Reinstantiate class
# t.__class__ = HearingsCollection

# %%
# Change directory
os.chdir('../../Data/')

# %% [markdown]
# <br>
#
# ## 1) Preparation: Loading, correcting and tidying the data

# %%
t = load('Hearings/02_witnesses.pkl')
with open('DeSmog/contrarian_actors.json', 'r') as jfile:
    contrarians = json.load(jfile)
with open('DeSmog/contrarian_organisations.json', 'r') as jfile:
    organisations = json.load(jfile)
print('We imported {} hearings, {} climate change contrarians and {} contrarianal organisations.'.format(len(t),len(contrarians),len(organisations)))
# Out:
# We imported 263 hearings, 480 climate change contrarians and 234 contrarianal organisations.

# %%
t.texts[0].keys()
# Out:
# dict_keys(['filename', 'identifier', 'content_raw', 'content', 'content_stripped', 'congress', 'climate_related', 'keywords_climate', 'keywords_carbonpricing', 'keywords_climatechange', 'title', 'date', 'year', 'committee', 'MODS', 'witnesses_MODS', 'witnesses_transcript', 'witnesses'])

# %%
# Correct wrongly scraped names
print(contrarians[3]['name'])
contrarians[3]['name'] = 'Arun Ahluwalia'
print(contrarians[3]['name'], '\n')

print(contrarians[244]['name'])
contrarians[244]['name'] = 'Steven Koonin'
print(contrarians[244]['name'], '\n')

print(contrarians[276]['name'])
contrarians[276]['name'] = 'Bjorn Lomborg'
print(contrarians[276]['name'], '\n')
# Out:
# Arun
# Arun Ahluwalia
#
# Steve Koonin
# Steven Koonin
#
# Bj
# Bjorn Lomborg

# %%
# Create base name for better matching (remove initials, nicknames and suffixes))
for i, contrarian in enumerate(contrarians):
    contrarians[i]['name_base'] = contrarians[i]['name']
# Remove leading inititals
    try:
        contrarians[i]['name_base'] = re.findall('^(?:\s?[A-Z]{1}\.{1}\s)(.+)', contrarians[i]['name'])[0]
    except:
        pass
# Remove middle inititals
    try:
        contrarians[i]['name_base'] = ' '.join(re.findall('(.+?)(?:\s?[A-Z]{1}\.{1}\s?|\s[A-Z]{2}\s){1,2}(.*)', contrarians[i]['name_base'])[0])
    except:
        pass
# Remove nicknames
    try:
        contrarians[i]['name_base'] = ' '.join(re.findall('(.+?)\s(?:\(.+?\))\s?(.+)?', contrarians[i]['name_base'])[0])
    except:
        pass
# Remove suffixes (except for Pielke Sr and Jr as both are contrarians)
    try:
        contrarians[i]['name_base'] = re.findall('(.+?)(?<!Pielke)(?:,?\s(Jr|Sr))', contrarians[i]['name_base'])[0][0]
    except:
        pass
# Remove special characters
    contrarians[i]['name_base'] = unidecode.unidecode(contrarians[i]['name_base'])

print('Here are some examples:\n')
print(contrarians[6]['name'], '-->', contrarians[6]['name_base'])
print(contrarians[56]['name'], '-->', contrarians[56]['name_base'])
print(contrarians[62]['name'], '-->', contrarians[62]['name_base'])
print(contrarians[408]['name'], '-->', contrarians[408]['name_base'])
# Out:
# Here are some examples:
#
# William JR Alexander --> William Alexander
# Robert L. Bradley Jr. --> Robert Bradley
# H. Sterling Burnett --> Sterling Burnett
# Robert C. Shoup (Bob Shoup) --> Robert Shoup

# %%
for i, contrarian in enumerate(contrarians):
    print(contrarians[i]['name_base'])
# Out:
# Tony Abbott
# John Stuart Agnew
# Alexandre Aguiar
# Arun Ahluwalia
# Syun-Ichi Akasofu
# Ralph Alexander
# William Alexander
# Claude Allegre
# Harry Alford
# Helmut Alt
# Gabriel Calzada Alvarez
# Klaus Angerer
# Bob Armstrong
# Martin Armstrong
# Scott Armstrong
# Jerome Arnett
# Ron Arnold
# Edward Atkin
# August Auer
# Dennis Avery
# Lawson Bader
# Ronald Bailey
# Steve Baker
# Joe Balash
# Sallie Baliunas
# Timothy Ball
# Whitney Ball
# Robert Balling
# Arron Banks
# George David Banks
# Steve Bannon
# Jack Barrett
# Joseph Bast
# Michael Bastasch
# Joe Bastardi
# Bryan Bateman
# Cody Battershill
# Charles Battig
# Bernard Beauzamy
# Calvin Beisner
# Larry Bell
# David Bellamy
# Tim Benson
# Richard Berman
# David Bernhardt
# James Bethell
# Roger Bezdek
# Paul Blair
# Godfrey Bloom
# Sonja Boehmer-Christiansen
# Andrew Bolt
# John Bolton
# Sir Nicholas Bonsor
# Christopher Booker
# Donald Boudreaux
# Alexandra Liddy Bourne
# Robert Bradley
# Jan Breslow
# Barry Brill
# Arthur Brooks
# Robert Bryce
# Reid Bryson
# Sterling Burnett
# Nigel Calder
# Alan Carlin
# Bob Carter
# Oren Cass
# Mike Catanzaro
# Lord Richard Hugh Cavendish
# John Charles
# Paul Chesser
# Christopher Chope
# John Christy
# Petr Chylek
# Ian Clark
# Frank Clemente
# Bonner Cohen
# Roger Cohen
# John Coleman
# Patrick Condon
# Joseph Conklin
# John Constable
# Russell Cook
# Amy Oliver Cooke
# Horace Cooper
# Paul Copper
# Piers Corbyn
# Roy Cordato
# Vincent Courtillot
# Richard Courtney
# Kevin Cramer
# Susan Crockford
# Ken Cuccinelli
# Walter Cunningham
# Judith Curry
# Joseph D'Aleo
# Rupert Darwall
# Edward David
# David Davies
# Robert Davis
# Donn Dears
# Anne Debeil
# James Delingpole
# David Deming
# Vincent DeVito
# Betsy DeVos
# Peter Dietze
# David Dilley
# Paul Driessen
# Harold Doiron
# Doug Domenech
# Lord Bernard Donoughue
# David Douglass
# Charles Drevna
# John Droz
# Reynald Du Berger
# Geoffrey Duffy
# John Dale Dunn
# William Dunn
# Freeman Dyson
# Don Easterbrook
# Gregg Easterbrook
# Myron Ebell
# Gunter Ederer
# Francis Egan
# Nathalie Elgrably-Levy
# Matthew Elliott
# Sarah Elliott
# Hugh Ellsaesser
# Gary England
# Alex Epstein
# Joni Ernst
# Marcus Ernst
# Willis Eschenbach
# Robert Essenhigh
# Christopher Essex
# David Evans
# Ray Evans
# Bruce Everett
# Friedrich-Karl Ewert
# Nigel Farage
# Peter Ferrara
# Walter Fett
# Chris Fink
# Richard Fink
# Travis Fisher
# Alex Fitzsimmons
# Joe Fone
# Viv Forbes
# Bob Foster
# Philip Foster
# Liam Fox
# Michael Fox
# Stewart Franks
# Chris de Freitas
# Gordon Fulks
# Samuele Furfari
# Dan Gainor
# Evelyn Browning-Garriss
# Jack Gerard
# Lee Gerhard
# Gerhard Gerlich
# Ivar Giaever
# Robert Giegengack
# Rudy Giuliani
# James K Glassman
# Steven Goddard
# Michael Goetz
# Indur Goklany
# Fred Goldberg
# Stanley Goldenberg
# Steve Goreham
# Laurence Gould
# Michael Gove
# Boyden Gray
# Vincent Gray
# William Gray
# Kenneth Green
# Kesten Green
# Andrew Grossman
# Ken Haapala
# Keith Hage
# Harold Hamm
# Matt Hancock
# Daniel Hannan
# William Happer
# Tom Harris
# Kathleen Hartnett-White
# Howard Hayden
# Steven Hayward
# Roger Helmer
# David Henderson
# David R Henderson
# Victor Manuel Velasco Herrera
# David Herro
# Hugh Hewitt
# Clay Higgins
# John Hinderaker
# Michael Hintze
# Kate Hoey
# Gertrud Hohler
# Derrick Hollie
# Jeffrey Holmstead
# Brian Hooks
# Art Horn
# Chris Horner
# Douglas Hoyt
# Tim Huelskamp
# Arthur Middleton Hughes
# Anne Idsal
# Craig Idso
# Sherwood Idso
# Keith Idso
# Laura Ingraham
# James Inhofe
# Niger Innis
# Roy Innis
# Kiminori Itoh
# Albert Jacobs
# Jeff Jacoby
# Zbigniew Jaworowski
# Boris Johnson
# Drew Johnson
# Claes Goran Johnson
# Alan Jones
# Alex Jones
# Daniel Jorjani
# Wibjorn Karlen
# William Kay
# Sam Kazman
# Richard Keen
# Don Keiller
# Michael Kelly
# Todd Kendall
# Phil Kerpen
# Madhav Khandekar
# Grant Kidwell
# William Kininmonth
# Charlie Kirk
# Gale Klappa
# Vaclav Klaus
# Chip Knappenberger
# Charles Koch
# David Koch
# Steven Koonin
# Gerrit Cornelis van Kooten
# Vivian Krause
# David Kreutzer
# George Kukla
# Hans Labohm
# Donna Laframboise
# Jim Lakely
# Jeff Landry
# Chris Landsea
# James Lankford
# Frank Lasee
# Nigel Lawson
# Ruth Lea
# Andrea Leadsom
# Douglas Leahey
# David Legates
# Jay Lehr
# Joe Leimkuhler
# Corey Lewandowski
# Bernie Lewin
# Ezra Levant
# Dan Lewis
# Marlo Lewis
# Peter Lilley
# Michael Limburg
# Richard Lindzen
# Gerrit van der Lingen
# John Loeffler
# Craig Loehle
# Angela Logomasini
# Simon Lomax
# Bjorn Lomborg
# Nicolas Loris
# Leon Louw
# Horst-Joachim Ludecke
# Sebastian Luning
# Anthony Lupo
# Harry MacDougald
# James Mahoney
# Augusto Mangini
# Jennifer Marohasy
# Henri Masson
# Mark Mathis
# Ryan Maue
# Amanda Maxham
# Mitch McConnell
# Charles McConnell
# Alister McFarquhar
# James McGrath
# Steve McIntyre
# Mike McKenna
# Ross McKitrick
# Owen McShane
# Robert Mendelsohn
# Rebekah Mercer
# Robert Mercer
# Patrick Michaels
# Fred Michel
# Steve Milloy
# Mark Mills
# Nick Minchin
# Asmunn Moene
# Annunziata Rees-Mogg
# Jacob Rees-Mogg
# Alan Moghissi
# Christopher Monckton
# Andrew Montford
# Patrick Moore
# Stephen Moore
# Marc Morano
# Terence Mordaunt
# Nils-Axel Morner
# Julian Morris
# Wolfgang Muller
# Mick Mulvaney
# Robert Murphy
# Iain Murray
# Tad Murty
# Todd Myers
# Maurice Newman
# Rodney Nichols
# Jeremy Nicholson
# Ned Nikolov
# Jacob Nordangard
# Sean Noble
# Bo Nordell
# John Nothdurft
# Joanne Nova
# William O'Keefe
# Oregon Petition
# John O'Sullivan
# Cliff Ollier
# Isaac Orr
# David Padden
# Lewis Page
# Fred Palmer
# Albert Parker
# Owen Paterson
# Timothy Patterson
# Gernot Patzelt
# Mikko Paunio
# George Pearson
# James Peden
# Benny Peiser
# Al Pekarek
# Cardinal George Pell
# Mike Pence
# Rick Perry
# Jordan Peterson
# Rachelle Peterson
# Nancy Pfotenhauer
# Tim Phillips
# Roger Pielke Jr.
# Roger Pielke Sr.
# Ben Pile
# Ian Plimer
# Dennis Prager
# Reince Priebus
# Harry Priem
# Mike Pompeo
# Art Pope
# Andreas Prokoph
# Scott Pruitt
# Jim Puplava
# Thomas Pyle
# Richard Rahn
# Vijay Kumar Raina
# Jim Ratcliffe
# Lee Raymond
# Neil Record
# John Redwood
# Josef Reichholf
# Paul Reiter
# Hubbel Relat
# Craig Richardson
# Peter Ridd
# Matt Ridley
# Gina Rinehart
# Malcolm Roberts
# Art Robinson
# Norman Rogers
# Brooke Rollins
# Arthur Rorsch
# David Rose
# Caleb Rossiter
# David Rothbard
# Craig Rucker
# Alan Rudge
# Burt Rutan
# Anthony Sadar
# Nicola Scafetta
# Rob Scagel
# Harrison Schmitt
# David Schnare
# Joel Schwartz
# Tom Segalstad
# Naomi Seibt
# Barre Seid
# Jim Sensenbrenner
# Frederick Seitz
# Nir Shaviv
# Gary Sharp
# Michael Shellenberger
# Robert Shoup
# Paavo Siitam
# Daniel Simmons
# Joanne Simpson
# Shanker Singham
# Fred Singer
# Vaclav Smil
# Fred Smith
# Graham Smith
# Lamar Smith
# Mike Sommers
# Willie Soon
# Lawrence Solomon
# James Spann
# Roy Spencer
# Sir James Spooner
# Ronald Stein
# Bret Stephens
# Leighton Steward
# Mark Steyn
# Graham Stringer
# John Stossel
# John Sununu
# Brian Sussman
# Henrik Svensmark
# Gordon Swaters
# Tom Tanton
# Roger Tattersall
# George Taylor
# James Taylor
# Thomasz Teluk
# Alexander Temerko
# Hendrik Tennekes
# Holger Thuss
# Rex Tillerson
# Utz Tillmann
# Richard Tol
# Donald Trump
# David Tuerck
# Fritz Vahrenholt
# Brian Valentine
# Jan Veizer
# Lord Nigel Vinson
# Arthur Viterito
# Greg Walcher
# James Wanliss
# Anthony Watts
# Gerd-Rainer Weber
# Werner Weber
# Edward Wegman
# William Wehrum
# Andrew Wheeler
# David Whitehouse
# Harry Wilkinson
# Dan Wilks
# Farris Wilks
# George Will
# Timothy Williams
# Sammy Wilson
# Wayne Winegarden
# Boris Winterhalter
# Bruno Wiskel
# David Wojick
# Joel Wood
# Todd Wynn
# Thomas Wysmuller
# Miklos Zagoni
# Karl Zeller
# Heather Zichal
# Antonino Zichichi
# Ryan Zinke
# Benjamin Zycher

# %% [markdown]
# <br>
#
# ## 2) Matching: match denialist witnesses giving testimony

# %% [markdown]
# ### Match names

# %%
count = 0
for i, text in enumerate(t.texts):
    t.texts[i]['desmog_witness'] = []
    for j, witness in enumerate(text['witnesses']):
        t.texts[i]['desmog_witness'].append(None)
        for contrarian in contrarians:
            ratio = fuzz.token_set_ratio(contrarian['name_base'],witness)
            if ratio >= 90:
                print(i, ratio, ': ',
                      witness,'\n\t',
                      contrarian['name_base'], '\n')
                count+=1
                t.texts[i]['desmog_witness'][j] = contrarian['name_base']
                break
            ratio = fuzz.partial_ratio(contrarian['name_base'],witness)
            if ratio > 92:
                print(i, ratio, ': ',
                      witness,'\n\t',
                      contrarian['name_base'], '\n')
                count+=1
                t.texts[i]['desmog_witness'][j] = contrarian['name_base']
                break
print('{} denialist witnesses were matched.'.format(count))
# Out:
# 1 100 :  Marlo Lewis, Senior Fellow, Competitive Enterprise Institute
# 	 Marlo Lewis
#
# 9 100 :  David W. Kreutzer, Ph.D., Senior Policy Analyst, The Heritage Foundation
# 	 David Kreutzer
#
# 19 100 :  Fred Smith, Chairman, President and Chief Executive Officer, FedEx Corporation
# 	 Fred Smith
#
# 19 100 :  Charles Drevna, President of the National Petrochemical and Refiners Association
# 	 Charles Drevna
#
# 27 100 :  Drevna, Charles T., President, National Petrochemical & Refiners Association
# 	 Charles Drevna
#
# 28 100 :  Beisner, E. Calvin, associate professor of Historical Theological and Social Ethics, Knox Theological Seminary; Spokesman for the Interfaith Stewardship Alliance
# 	 Calvin Beisner
#
# 28 100 :  Lomborg, Bjorn, adjunct professor, Copenhagen Consensus Center
# 	 Bjorn Lomborg
#
# 32 100 :  Robert Bradley, Director Of International Climate Policy, World Resources Institute
# 	 Robert Bradley
#
# 37 100 :  Jack Gerard, National Mining Association
# 	 Jack Gerard
#
# 40 94 :  Hon. Jeffery Holmstead, Assistant Administrator For Air And Radiation, Environmental Protection Agency
# 	 Jeffrey Holmstead
#
# 47 100 :  Rex Tillerson, Chairman and CEO, ExxonMobil Corporation
# 	 Rex Tillerson
#
# 48 100 :  Lawson of Blaby, Lord Nigel, House of Lords, United Kingdom
# 	 Nigel Lawson
#
# 52 100 :  Steven F. Hayward, F.K. Weyerhaeuser Fellow in Law and Economics, American Enterprise Institute
# 	 Steven Hayward
#
# 61 100 :  Dr. David Kreutzer, Senior Policy Analyst, Heritage Foundation
# 	 David Kreutzer
#
# 64 100 :  Kenneth P. Green, Ph.D., Resident Scholar, American Enterprise Institute
# 	 Kenneth Green
#
# 65 100 :  Christy, Dr. John R., Alabama State Climatologist, Huntsville, Alabama
# 	 John Christy
#
# 74 100 :  Dr. Kenneth P. Green, Resident Scholar, American Enterprise Institute, Washington, D.C.
# 	 Kenneth Green
#
# 84 100 :  Patrick J. Michaels, Senior Fellow in Environmental Studies, Cato Institute
# 	 Patrick Michaels
#
# 93 100 :  Akasofu, Dr. Syun-Ichi, Director, International Arctic Research Center, University of Alaska Fairbanks
# 	 Syun-Ichi Akasofu
#
# 93 100 :  Reiter, Paul, Chief, Insects and Infectious Disease Unit; Professor, Institut Pasteur
# 	 Paul Reiter
#
# 95 100 :  Christy, John R., Professor of Atmospheric Science, and Director of the Earth System Science Center, University of Alabama in Huntsville, and Alabama's State Climatologist
# 	 John Christy
#
# 101 100 :  Ball, Dr. Timothy F., Chair, Natural Resources Stewardship Project
# 	 Timothy Ball
#
# 103 100 :  Judith Curry, Chair, School Of Earth And Atmospheric Sciences, Georgia Institute Of Technology
# 	 Judith Curry
#
# 103 100 :  John R. Christy, Professor And Director, Earth System Science Center, Nsstc, University Of Alabama In Huntsville
# 	 John Christy
#
# 103 100 :  Roger A. Pielke, Jr., Center For Science And Technology Policy Research, University Of Colorado At Boulder
# 	 Roger Pielke Jr.
#
# 109 100 :  Roy Spencer, University Of Alabama, Huntsville
# 	 Roy Spencer
#
# 112 100 :  Murray, Iain, Vice President for Strategy, Competitive Enterprise Institute
# 	 Iain Murray
#
# 113 100 :  Green, Dr. Kenneth P., resident scholar, American Enterprise Institute for Public Policy Research, Washington, DC
# 	 Kenneth Green
#
# 114 100 :  Lewis, Marlo, Senior Fellow, Competitive Enterprise Institute
# 	 Marlo Lewis
#
# 115 100 :  Green, Kenneth P., Ph.D., Resident Scholar, American Enterprise Institute, prepared statement
# 	 Kenneth Green
#
# 120 100 :  Rex W. Tillerson, Chairman and Chief Executive Officer, Exxon Mobil
# 	 Rex Tillerson
#
# 126 100 :  Charles Drevna, executive vice president, National Petrochemical and Refiners Association
# 	 Charles Drevna
#
# 136 100 :  Coleman, John, Senior Meteorologist, KUSI, San Diego, California
# 	 John Coleman
#
# 151 100 :  Mathis, Mark, President, Confluence Energy, Kremmling, Colorado
# 	 Mark Mathis
#
# 155 100 :  Green, Kenneth P., Resident Scholar, American Enterprise Institute for Public Policy Research
# 	 Kenneth Green
#
# 157 100 :  Mr. Kenneth Green, American Enterprise Institute
# 	 Kenneth Green
#
# 161 100 :  Bast, Joseph, President, The Heartland Institute
# 	 Joseph Bast
#
# 172 100 :  Mahoney, James R., Ph.D., Environmental Consultant
# 	 James Mahoney
#
# 176 100 :  John R. Christy, professor and director, Earth System Science Center, NSSTC, University of Alabama in Huntsville, Huntsville, AL
# 	 John Christy
#
# 178 100 :  Steven F. Hayward, American Enterprise Institute
# 	 Steven Hayward
#
# 179 100 :  Sharp, Dr. Gary D., Ph.D., Scientific Director, Center for Climate/Ocean Resources Study
# 	 Gary Sharp
#
# 193 100 :  Dr. Richard S. Lindzen, Alfred P. Sloan Professor Of Meteorology, Department Of Earth Atmospheric And Planetary Science, Massachusetts Institute Of Technology Oral Statement
# 	 Richard Lindzen
#
# 193 100 :  Dr. Patrick J. Michaels, Senior Fellow In Environmental Studies, Cato Institute Oral Statement
# 	 Patrick Michaels
#
# 193 100 :  Dr. Judith A. Curry, Chair Of The School Of Earth And Atmospheric Sciences, Georgia Institute Of Technology Oral Statement
# 	 Judith Curry
#
# 194 100 :  Mr. Myron Ebell, Director, Energy and Global Warming Policy, Competitive Enterprise Institute
# 	 Myron Ebell
#
# 198 100 :  Ross McKitrick, Associate Professor and Director of Graduate Studies, Department of Economics, University of Guelph
# 	 Ross McKitrick
#
# 198 100 :  Roger A. Pielke, Sr., Senior Research Scientist (CIRES), Senior Research Associate (ATOC), University of Colorado, Boulder
# 	 Roger Pielke Sr.
#
# 204 100 :  Winegarden, Wayne, Partner, Arduin, Laffer and Moore Econometrics
# 	 Wayne Winegarden
#
# 204 100 :  Green, Kenneth, Visiting Fellow, American Enterprise Institute for Public Policy Research
# 	 Kenneth Green
#
# 213 100 :  Dr. Roger A. Pielke, Jr., Professor of Environmental Studies Program at the University of Colorado and Director of the Center for Science and Technological Policy Research
# 	 Roger Pielke Jr.
#
# 215 100 :  Spencer, Roy W., Principal Research Scientist, Earth System Science Center, University of Alabama, Huntsville
# 	 Roy Spencer
#
# 218 100 :  Mahoney, Hon. James R. Ph.D., Assistant Secretary of Commerce for Oceans and Atmosphere, Department of Commerce, and Director, U.S. Climate Change Science Program
# 	 James Mahoney
#
# 220 100 :  Bjorn Lomborg, adjunct professor, Copenhagen Consensus Center, Copenhagen Business School, Copenhagen, Denmark
# 	 Bjorn Lomborg
#
# 231 100 :  Dr. Steven Hayward, F.K. Weyerhaeuser Fellow, American Enterprise Institute
# 	 Steven Hayward
#
# 231 100 :  David Kreutzer, Senior Policy Analyst in Energy Economics and Climate Change, The Heritage Foundation
# 	 David Kreutzer
#
# 231 100 :  Myron Ebell, Director, Energy and Global Warming Policy, Competitive Enterprise Institute
# 	 Myron Ebell
#
# 231 100 :  Charles T. Drevna, President, National Petrochemical and Refiners Association
# 	 Charles Drevna
#
# 236 100 :  Dr. Judith A. Curry, Professor and Chair, School of Earth and Atmospheric Science, Georgia Institute of Technology
# 	 Judith Curry
#
# 237 100 :  Dr. John Christy, Distinguished Professor of Atmospheric Science and Director of the Earth System Science Center, University of Alabama in Huntsville, Huntsville, Alabama
# 	 John Christy
#
# 256 100 :  Smith, Fred L. Jr., President, Competitive Enterprise Institute
# 	 Fred Smith
#
# 256 100 :  Hamm, Harold, Chairman of the Board, Chief Executive Office, Continental Resources, Inc
# 	 Harold Hamm
#
# 262 100 :  Deming, David, Ph.D., University of Oklahoma, College of Earth and Energy
# 	 David Deming
#
# 262 100 :  Gainor, Dan, The Boone Pickens Free Market Fellow, director, Business & Media Institute
# 	 Dan Gainor
#
# 63 denialist witnesses were matched.

# %%
# # Search for for further matches
# count = 0
# for i, text in enumerate(t.texts):
#     for j, witness in enumerate(text['witnesses']):
#         if t.texts[i]['desmog'][j] == None:
#             for contrarian in contrarians:
#                 ratio = fuzz.partial_ratio(contrarian['name_base'],unidecode.unidecode(witness))
#                 if ratio >= 90:
#                     print(i, ratio, ': ',
#                           witness,'\n\t',
#                           contrarian['name_base'], '\n')
#                     count+=1
#                     break
# print('{} further denialist witnesses were matched.'.format(count))

# %% [markdown]
# ### Match organisations

# %%
count = 0
for i, text in enumerate(t.texts):
    t.texts[i]['desmog_organisation'] = []
    for j, witness in enumerate(text['witnesses']):
        t.texts[i]['desmog_organisation'].append(None)
        for organisation in organisations:
            ratio = fuzz.partial_ratio(organisation['name'].lower(),witness.lower())
            if ratio >= 90:
                print(i, ratio, ': ',
                      witness,'\n\t',
                      organisation['name'], '\n')
                count+=1
                t.texts[i]['desmog_organisation'][j] = organisation['name']
                break
print('{} denialist witnesses were matched.'.format(count))
# Out:
# 0 100 :  Margo Thorning, Ph.D., Senior Vice President and Chief Economist, American Council for Capital Formation
# 	 American Council for Capital Formation
#
# 1 100 :  Lee Lane, Resident Fellow, American Enterprise Institute
# 	 American Enterprise Institute
#
# 1 100 :  Marlo Lewis, Senior Fellow, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 6 100 :  Margo Thorning, Ph.D., Senior Vice President and Chief Economist, American Council for Capital Formation
# 	 American Council for Capital Formation
#
# 9 100 :  David W. Kreutzer, Ph.D., Senior Policy Analyst, The Heritage Foundation
# 	 Heritage Foundation
#
# 15 100 :  Thomas F. Farrell, Ii, Chairman, President And Ceo, Dominion (On Behalf Of Edison Electric Institute)
# 	 Edison Electric Institute
#
# 16 100 :  Mr. Lee Lane, Resident Fellow, American Enterprise Institute
# 	 American Enterprise Institute
#
# 28 100 :  Lomborg, Bjorn, adjunct professor, Copenhagen Consensus Center
# 	 Copenhagen Consensus Center
#
# 37 100 :  Jack Gerard, National Mining Association
# 	 National Mining Association
#
# 37 100 :  David Owens, Executive Vice President, Edison Electric Institute
# 	 Edison Electric Institute
#
# 42 95 :  Mark Esper, Executive Vice President, Global Intellectual Property Center, U.S. Chamber Of Commerce
# 	 US Chamber of Commerce
#
# 45 95 :  Thorning, Margo, Ph.D., senior vice president and chief economist, American Counsel for Capital Formation
# 	 American Council for Capital Formation
#
# 48 100 :  Thorning, Margo, Ph.D., Senior Vice President and Chief Economist, American Council for Capital Formation
# 	 American Council for Capital Formation
#
# 51 100 :  John Felmy, Chief Economist, American Petroleum Institute
# 	 American Petroleum Institute
#
# 52 100 :  Steven F. Hayward, F.K. Weyerhaeuser Fellow in Law and Economics, American Enterprise Institute
# 	 American Enterprise Institute
#
# 61 100 :  Dr. David Kreutzer, Senior Policy Analyst, Heritage Foundation
# 	 Heritage Foundation
#
# 64 100 :  Kenneth P. Green, Ph.D., Resident Scholar, American Enterprise Institute
# 	 American Enterprise Institute
#
# 66 100 :  Rogers, James, CEO and President, Cinergy Corporation, on behalf of the Edison Electric Institute
# 	 Edison Electric Institute
#
# 66 100 :  Thorning, Margo, senior vice president and chief economist, American Council for Capital Formation
# 	 American Council for Capital Formation
#
# 68 95 :  William Kovacs, Vice President, Environment, Technology And Regulatory Affairs, U.S. Chamber Of Commerce
# 	 US Chamber of Commerce
#
# 68 100 :  James L. Gattuso, Research Fellow In Regulatory Policy, The Heritage Foundation
# 	 Heritage Foundation
#
# 71 100 :  Mr. Lee Lane, Co-Director, American Enterprise Institute (Aei) Geoengineering Project Oral Statement
# 	 American Enterprise Institute
#
# 74 100 :  Dr. Kenneth P. Green, Resident Scholar, American Enterprise Institute, Washington, D.C.
# 	 American Enterprise Institute
#
# 76 95 :  The Honorable Karen Harbert, President and Chief Executive Officer, Institute for 21st Century Energy, U.S. Chamber of Commerce
# 	 US Chamber of Commerce
#
# 84 100 :  Patrick J. Michaels, Senior Fellow in Environmental Studies, Cato Institute
# 	 Cato Institute
#
# 85 95 :  Janet Kavinoky, Director, Transportation Infrastructure Congressional & Public Affairs and Executive Director, Americans for Transportation Mobility Coalition, United States Chamber of Commerce
# 	 US Chamber of Commerce
#
# 101 100 :  Ball, Dr. Timothy F., Chair, Natural Resources Stewardship Project
# 	 Natural Resources Stewardship Project
#
# 112 100 :  Murray, Iain, Vice President for Strategy, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 113 100 :  Green, Dr. Kenneth P., resident scholar, American Enterprise Institute for Public Policy Research, Washington, DC
# 	 American Enterprise Institute
#
# 113 100 :  Thorning, Dr. Margo, senior vice president and chief economist, American Council for Capital Formation, Washington, DC
# 	 American Council for Capital Formation
#
# 113 100 :  Hatch, Hon. Orrin G.: Prepared statement of Americans for Tax Reform
# 	 Americans for Tax Reform
#
# 113 100 :  American Petroleum Institute
# 	 American Petroleum Institute
#
# 114 95 :  Kovacs, Bill, Vice President, Environment, Technology and Regulatory Affairs, U.S. Chamber of Commerce
# 	 US Chamber of Commerce
#
# 114 100 :  Lewis, Marlo, Senior Fellow, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 115 100 :  Carafano, James Jay, Lieutenant Colonel, U.S. Army (retired); Deputy Director, the Kathryn and Shelby Cullom Davis Institute for International Studies; Director, Douglas and Sarah Allison Center for Foreign Policy Studies, The Heritage Foundation
# 	 Heritage Foundation
#
# 115 100 :  Green, Kenneth P., Ph.D., Resident Scholar, American Enterprise Institute, prepared statement
# 	 American Enterprise Institute
#
# 117 100 :  Parady, Fred, manager, Environmental Services, OCI Wyoming, L.P., on behalf of the National Association of Manufacturers
# 	 National Association of Manufacturers
#
# 118 100 :  Steve Miller, President and CEO, American Coalition For Clean Coal Electricity
# 	 American Coalition for Clean Coal Electricity
#
# 137 95 :  Christopher Wenk, Senior Director, International Policy, U.S. Chamber of Commerce
# 	 US Chamber of Commerce
#
# 141 91 :  Harbert, Karen A., Executive Vice President And Managing Director, Institute For 21St Century Energy, Chamber Of Commerce
# 	 US Chamber of Commerce
#
# 143 91 :  Harbert, Karen, President And Ceo, Institute For 21St Century Energy, Chamber Of Commerce
# 	 US Chamber of Commerce
#
# 145 91 :  Fisher, Michael, president, Greater Cincinnati Chamber of Commerce
# 	 US Chamber of Commerce
#
# 155 100 :  Green, Kenneth P., Resident Scholar, American Enterprise Institute for Public Policy Research
# 	 American Enterprise Institute
#
# 157 100 :  Mr. Kenneth Green, American Enterprise Institute
# 	 American Enterprise Institute
#
# 161 100 :  Bast, Joseph, President, The Heartland Institute
# 	 Heartland Institute
#
# 166 95 :  Harbert, Karen A., President & CEO, Institute for 21st Century Energy, U.S. Chamber of Commerce
# 	 US Chamber of Commerce
#
# 166 100 :  Nichols, J. Larry, Chairman and Chief Executive Officer, Devon Energy Corporation, on behalf of the American Petroleum Institute
# 	 American Petroleum Institute
#
# 167 100 :  Ben Lieberman, Senior Policy Analyst For Energy And Environment, Thomas A. Roe Institute For Economic Policy Studies, Heritage Foundation, Washington, Dc
# 	 Heritage Foundation
#
# 170 100 :  Butler, Stuart M., Dr.; Vice President for Domestic and Economic Policy Studies, The Heritage Foundation .................... 401,
# 	 Heritage Foundation
#
# 178 100 :  Steven F. Hayward, American Enterprise Institute
# 	 American Enterprise Institute
#
# 180 100 :  Jack Spencer, Research Fellow In Nuclear Energy, Thomas A. Roe Institute For Economic Policy Studies, The Heritage Foundation
# 	 Heritage Foundation
#
# 180 95 :  Christopher Guith, Vice President Of Public Policy, U.S. Chamber Of Commerce
# 	 US Chamber of Commerce
#
# 193 100 :  Dr. Patrick J. Michaels, Senior Fellow In Environmental Studies, Cato Institute Oral Statement
# 	 Cato Institute
#
# 194 100 :  Mr. Myron Ebell, Director, Energy and Global Warming Policy, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 197 100 :  kraig r. naasz, president and chief executive officer, national mining association
# 	 National Mining Association
#
# 197 100 :  glenn kelly, vice president, government affairs, national mining association
# 	 National Mining Association
#
# 197 100 :  Thomas R. Kuhn, President, Edison Electric Institute
# 	 Edison Electric Institute
#
# 197 100 :  John Felmy, Chief Economist, American Petroleum Institute
# 	 American Petroleum Institute
#
# 204 100 :  Armey, Richard K., Chairman, Freedomworks
# 	 FreedomWorks
#
# 204 100 :  Green, Kenneth, Visiting Fellow, American Enterprise Institute for Public Policy Research
# 	 American Enterprise Institute
#
# 220 100 :  Bjorn Lomborg, adjunct professor, Copenhagen Consensus Center, Copenhagen Business School, Copenhagen, Denmark
# 	 Copenhagen Consensus Center
#
# 223 100 :  Margo Thorning, Senior Vice President And Chief Economist, American Council For Capital Formation
# 	 American Council for Capital Formation
# 223 100 :  Michael Morris, Chairman Of The Board Of Directors, Edison Electric Institute
# 	 Edison Electric Institute
#
# 223 100 :  Craig Montesano, Director Of Governmental Affairs, National Mining Association
# 	 National Mining Association
#
# 231 100 :  Dr. Steven Hayward, F.K. Weyerhaeuser Fellow, American Enterprise Institute
# 	 American Enterprise Institute
#
# 231 100 :  David Kreutzer, Senior Policy Analyst in Energy Economics and Climate Change, The Heritage Foundation
# 	 Heritage Foundation
#
# 231 100 :  Myron Ebell, Director, Energy and Global Warming Policy, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 231 100 :  Jeffry E. Sterba, Chairman and CEO, PNM Resources Inc., On Behalf of the Edison Electric Institute
# 	 Edison Electric Institute
#
# 231 100 :  Lee Lane, Resident Fellow, American Enterprise Institute
# 	 American Enterprise Institute
#
# 231 95 :  William L. Kovacs, Vice President, Environment, Technology and Regulatory Affairs, U.S. Chamber of Commerce
# 	 US Chamber of Commerce
#
# 242 100 :  Dr. Margo Thorning, Senior Vice President and Chief Economist, American Council for Capital Formation
# 	 American Council for Capital Formation
#
# 251 100 :  Randal O'Toole, Senior Fellow, The Cato Institute
# 	 Cato Institute
#
# 256 100 :  Smith, Fred L. Jr., President, Competitive Enterprise Institute
# 	 Competitive Enterprise Institute
#
# 73 denialist witnesses were matched.

# %%
# count = 0
# for i, text in enumerate(t.texts):
#     for j, witness in enumerate(text['witnesses']):
#         if t.texts[i]['desmog_organisation'][j] == None:
#             for organisation in organisations:
#                 ratio = fuzz.token_sort_ratio(re.sub(r'\s*\((.+)\)\s*', ' ',organisation['name'].lower()).strip(),witness.lower())
#                 if ratio >= 90:
#                     print(i, ratio, ': ',
#                           witness,'\n\t',
#                           organisation['name'], '\n')
#                     count+=1
#                     break

# print('{} denialist witnesses were matched.'.format(count))

# %% [markdown]
# <br>
#
# ### Summary

# %%
# Summary:
denialists = 0
denialists_hearings = 0

for text in t.texts:
    denialists_present = False
    for i, witness in enumerate(text['witnesses']):
            if text['desmog_witness'][i] != None or text['desmog_organisation'][i] != None:
                denialists += 1
                denialists_present = True
    if denialists_present:
        denialists_hearings += 1
                

print('{} denialists were found at {} of the {} hearings.\n\n'.format(denialists, denialists_hearings, len(t)))
# Out:
# 110 denialists were found at 75 of the 263 hearings.

# %% [markdown]
# <br>
#
# ### Save data

# %%
# Run for maximum recursion error during saving

import resource
import sys

print(resource.getrlimit(resource.RLIMIT_STACK))
print(sys.getrecursionlimit())

# May segfault without this line. 0x100 is a guess at the size of each stack frame.
max_rec = 0x100000
resource.setrlimit(resource.RLIMIT_STACK, [0x100 * max_rec, resource.RLIM_INFINITY])
sys.setrecursionlimit(max_rec)

print(sys.getrecursionlimit())
# Out:
# (8388608, -1)
# 3000
# 1048576

# %%
save_as(t, 'Hearings/03_desmog_witnesses.pkl') # Last completed on Oct 30, 2020
